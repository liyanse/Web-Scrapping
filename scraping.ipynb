# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url="https://hotelbars.guide/diani-beach/"

# %%
req=requests.get(url)

# %%
url1=pd.DataFrame([url])

# %%
url1.head()
# Out:
#                                     0
# 0  https://visitdiani.com/activities/

# %%
req.content
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 9]><script src="https://visitdiani.com/wp-content/themes/bookyourtravel/BookYourTravel/js/html5shiv.js"></script><![endif]--><html lang="en-US"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"> <script>window.currentUrl="https:\\/\\/visitdiani.com\\/activities?pagename=activities";window.themePath="https:\\/\\/visitdiani.com\\/wp-content\\/themes\\/bookyourtravel\\/BookYourTravel";window.currentUserId=0;window.datepickerDateFormat="MM d, yy";window.datepickerAltFormat="yy-mm-dd";window.siteUrl="https:\\/\\/visitdiani.com";window.wooCartPageUri="https:\\/\\/visitdiani.com\\/checkout\\/";window.useWoocommerceForCheckout=1;window.enableRtl=!1;window.currencySymbol="KSh";window.currencySymbolShowAfter=0;window.priceDecimalPlaces=0;window.gdprError=\'Agreeing with gdpr terms and conditions is required!\'</script> <title>Activities &#8211; visitdiani.com</title><meta name=\'robots\' content=\'max-image-preview:
# ...

# %%
# Create a BeautifulSoup object
soup = BeautifulSoup(req.text, 'html.parser')

# %%
summary=soup.get_text()

# %%
#to get the proper data. to get ans for our question.
print(summary)
# Out:
#   Activities – visitdiani.com
#
#      blogcontactjoin usaccount
#
# KES, KshUSD, $EUR, €
# WPCS 2.1.4
#
# MENUDealsVillasHotelsToursActivitiesWine & DineTravel WiseDiani Beach FAQsFlying to and from DianiFirst time in DianiSwahili GreetingsEventsDestinationsDianiMombasaKilifiWatamuMalindiLamuMy accountBlogContact Us
# shopping_cart 0Activities Find activityWhat?TourWhat type of activity?What type of activity?BeachBushCultureFoodHealthHikingNaturePartySportReview score010Price range1 - 5,000 KSh5,001 - 10,000 KSh10,001 - 15,000 KSh15,001 KSh +×    20 activities foundPrice ascendingdescendingRating ascendingdescendingBoat Trip with 2 dives 🛥️
# Diani Marine
#
#
# Terrible
# 1 review 0/10
# Diani, Diani Beach Road, Diani Marine
# The price for this course is 109 euros. It can be paid in KES or USD based on...
#  per person
#
# KSh
#
#
#
#
#
# Book NowDiscover Scuba Diver Course
# Diani Marine
#
#
# Terrible
# 1 review 0/10
# Diani, Diani Beach, Diani Marine
# ...

# %%
summary1=pd.DataFrame([summary])

# %%
summary1.head()
# Out:
#                                                    0
# 0  \n  Activities – visitdiani.com            \n\...

# %%
#To request tital of url
res=soup.title

# %%
print(res.prettify())
# Out:
# <title>
#  Activities – visitdiani.com
# </title>

# %%
print(res.get_text())
# Out:
# Activities – visitdiani.com

# %%
title1=pd.DataFrame([res])

# %%
title1.head()
# Out:
#                              0
# 0  Activities – visitdiani.com

# %%
data=[url,res,summary]

# %%
data
# Out:
# ['https://visitdiani.com/activities/',
#  <title>Activities – visitdiani.com</title>,
# ...

# %%
result=pd.concat([url1,title1,summary1])

# %%
result
# Out:
#                                                    0
# 0                 https://visitdiani.com/activities/
# 0                        Activities – visitdiani.com
# 0  \n  Activities – visitdiani.com            \n\...

# %%
result = pd.concat([url1, title1, summary1], axis=1)

# Save the concatenated data to a text file
result.to_csv('activities.txt', index=False, sep='\t')
